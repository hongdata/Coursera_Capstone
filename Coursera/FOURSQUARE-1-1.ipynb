# %% [markdown]
# # FOURSQUARE ASSIGNMENT

# %% [markdown]
# ## Description
# I work for J.W Mriott Dong-Dae-Moon in KOREA. (not really)
# I would like to recommend good restaurant nearby our hotel for out guest.
# For this problem i will use FOURSQUARE API

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20190408'
LIMIT = 30

# %%
address = '종로구 청계천로 279'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
search_query = '식당'
radius = 1000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)

# %%
dataframe
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 1  [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 3  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 5  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 6  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 7  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 8  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
#
#                          id    location.address location.cc location.city  \
# 0  4cc8fee9786e4688179c9109                 NaN          KR           NaN
# 1  4de8c5251838b9ad8d15f5c1                 NaN          KR           NaN
# 2  4f436d18e4b09d14bc73f79c           장충단로8길 45          KR            중구
# 3  50b88032e4b026fe4a2753ee                 NaN          KR           NaN
# 4  4f7d60e5e4b09d3099e463d7                 NaN          KR           NaN
# 5  537ac6aa498ea6fcc48f2b72        중구 다산로40길 56          KR           NaN
# 6  4bd2c194b221c9b63440d8d0  종로구 종로51가길 2-1, 2층          KR         서울특별시
# 7  4c516304375c0f47dcd7de93        종로구 종로40가길 5          KR           종로구
# 8  4c3c554b86ce328f808bab2d         종로구 효제동 145          KR         서울특별시
#
#   location.country location.crossStreet  location.distance  \
# 0             대한민국                  NaN                244
# 1             대한민국                  NaN                865
# 2             대한민국                  NaN                930
# 3             대한민국                  NaN                874
# 4             대한민국                  NaN                941
# 5             대한민국                  NaN                946
# 6             대한민국                 동대문점                293
# 7             대한민국                  NaN                544
# 8             대한민국                  NaN                879
#
#                            location.formattedAddress  \
# 0                                        [광희동, 대한민국]
# 1                                       [숭인1동, 대한민국]
# 2                    [장충단로8길 45, 장충동, 중구, 경기도, 대한민국]
# 3                                        [광희동, 대한민국]
# 4                                       [신당1동, 대한민국]
# 5                  [중구 다산로40길 56, 신당5동, 서울특별시, 대한민국]
# 6  [종로구 종로51가길 2-1, 2층 (동대문점), 창신1동, 서울특별시, 03105...
# 7   [종로구 종로40가길 5, 종로5.6가동, 종로구, 서울특별시, 03197, 대한민국]
# 8         [종로구 효제동 145, 종로5.6가동, 서울특별시, 서울특별시, 대한민국]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 37.567874, 'lng':...     37.567874
# 1  [{'label': 'display', 'lat': 37.57740002525583...     37.577400
# 2  [{'label': 'display', 'lat': 37.562265, 'lng':...     37.562265
# 3  [{'label': 'display', 'lat': 37.56476331656288...     37.564763
# 4  [{'label': 'display', 'lat': 37.561636, 'lng':...     37.561636
# 5  [{'label': 'display', 'lat': 37.563195, 'lng':...     37.563195
# 6  [{'label': 'display', 'lat': 37.57256693674935...     37.572567
# 7  [{'label': 'display', 'lat': 37.57033841616129...     37.570338
# 8  [{'label': 'display', 'lat': 37.57303636069216...     37.573036
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    127.011671                   NaN                 NaN            NaN
# 1    127.015376                   NaN                 NaN            NaN
# 2    127.008423                   NaN                 NaN            경기도
# 3    127.005162                   NaN                 NaN            NaN
# 4    127.010536                   NaN                 NaN            NaN
# 5    127.019166                   NaN                 NaN          서울특별시
# 6    127.012588                   NaN               03105            NaN
# 7    127.006468                  종로5가               03197          서울특별시
# 8    127.003447                   NaN                 NaN          서울특별시
#
#               name    referralId
# 0            보원 식당  v-1554653563
# 1           청포도 식당  v-1554653563
# 2           서씨네 식당  v-1554653563
# 3       깔링까 러시아 식당  v-1554653563
# 4           가마솥 식당  v-1554653563
# 5         형제정육점 식당  v-1554653563
# 6  EVEREST (에베레스트)  v-1554653563
# 7              전주집  v-1554653563
# 8            노다지품바  v-1554653563
